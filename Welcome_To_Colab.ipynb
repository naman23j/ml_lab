# %% [markdown]
# <a href="https://colab.research.google.com/github/naman23j/ml_lab/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MACHINE LEARNING LAB

# %%
pip install pandas

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/Data2.csv')
display(df.head())
# Out:
#    example citations    size inLibrary       price editions  buy
# 0        1      some   small        no  affordable     many   no
# 1        2      many     big        no   expensive      one  yes
# 2        3      some     big    always   expensive      few   no
# 3        4      many  medium        no   expensive     many  yes
# 4        5      many   small        no   expensive     many  yes

# %% [markdown]
# ### Steps to Analyze a CSV File:
#
# 1.  **Load the Data**: Read the CSV file into a pandas DataFrame.
# 2.  **Initial Data Inspection**: Understand the structure, data types, and basic statistics.
# 3.  **Handle Missing Values**: Identify and address any missing data.
# 4.  **Data Cleaning and Preparation**: Standardize formats, correct inconsistencies, and convert data types if necessary.
# 5.  **Exploratory Data Analysis (EDA)**: Visualize distributions, relationships, and patterns.
# 6.  **Feature Engineering**: Create new features to enhance analysis or model building (if applicable).
# 7.  **Further Analysis/Modeling**: Depending on your goal, perform statistical analysis or build predictive models.
#
# Let's start by loading the CSV file. Please choose one of the available files (`/content/Data3.csv`, `/content/Data2.csv`, `/content/Data.csv`) or specify your own file path.

# %%
# To get started, let's load one of your CSV files into a pandas DataFrame and display the first few rows.
# Replace 'your_file_name.csv' with the actual path to your CSV file.

# Example: df = pd.read_csv('/content/Data.csv')
# display(df.head())

# %%
df
# Out:
#    example citations    size inLibrary       price editions  buy
# 0        1      some   small        no  affordable     many   no
# 1        2      many     big        no   expensive      one  yes
# 2        3      some     big    always   expensive      few   no
# 3        4      many  medium        no   expensive     many  yes
# 4        5      many   small        no   expensive     many  yes

# %%
concepts = np.array(df)[:,:-1]

# %%
concepts
# Out:
# array([[1, 'some', 'small', 'no', 'affordable', 'many'],
#        [2, 'many', 'big', 'no', 'expensive', 'one'],
#        [3, 'some', 'big', 'always', 'expensive', 'few'],
#        [4, 'many', 'medium', 'no', 'expensive', 'many'],
#        [5, 'many', 'small', 'no', 'expensive', 'many']], dtype=object)

# %%
target = np.array(df)[:,-1]
target
# Out:
# array(['no', 'yes', 'no', 'yes', 'yes'], dtype=object)

# %%
def train(con , tar):
  for i, val in enumerate(tar):
    if val == 'yes':
      specific_h = con[i].copy()
      break
  for i, val in enumerate(con):
    if tar[i] == 'yes':
      for x in range(len(specific_h)):
        if val[x] != specific_h[x]:
          specific_h[x] = '?'
        else:
          pass
  return specific_h

# %%
print(train(concepts,target))
# Out:
# ['?' 'many' '?' 'no' 'expensive' '?']
